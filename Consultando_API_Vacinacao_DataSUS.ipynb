# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('gbSRoLZoFhI')

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import json

# %%
url = "https://imunizacao-es.saude.gov.br/_search"

# %%
# payload= ""
# headers = {
#   'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k='
# }
# response = requests.request("GET", url, headers=headers, data=payload)
# print(response.text)

# %%
# r = requests.get(url, auth=HTTPBasicAuth('imunizacao_public', 'qlto5t&7r_@+#Tlstigi'))

# %%
playload = json.dumps({
    "size": 10000
})
headers = {
    'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k=',
    'Content-Type': 'application/json',
    'Cookie': 'ELASTIC-PROD=1618079452.839.9136.791476'
}
response = requests.request("POST", url, headers=headers, data=payload)
print(response.text)
# Out:
# {"took":9,"timed_out":false,"_shards":{"total":30,"successful":30,"skipped":0,"failed":0},"hits":{"total":{"value":10000,"relation":"gte"},"max_score":1.0,"hits":[{"_index":"desc-imunizacao-v5","_type":"_doc","_id":"5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0","_score":1.0,"_source":{"sistema_origem":"Novo PNI","paciente_endereco_coPais":"10","vacina_codigo":"87","vacina_fabricante_nome":"PFIZER","vacina_nome":"COVID-19 PFIZER - COMIRNATY","estabelecimento_razaoSocial":"PREFEITURA MUNICIPAL DE FEIRA DE SANTANA","paciente_enumSexoBiologico":"M","paciente_endereco_uf":"BA","data_importacao_rnds":"2022-02-23T02:54:50.000Z","paciente_racaCor_valor":"SEM INFORMACAO","vacina_categoria_codigo":"2","estabelecimento_valor":"2401533","paciente_id":"f9fcda12d805c5a751c3dbdaf58e86dc2048c6ea057d3e3e6396da07273768d4","vacina_lote":"FM3457","data_importacao_datalake":"2022-08-21T18:14:52.000Z","estabelecimento_uf":"BA","@timestamp":"2022-08-21T21:15:50.452Z","paciente_nacionalidade_enumNacionalidade":"B","estabelecimento_municipio_codigo":"291080","vacina_descricao_dose":"Reforço","vacina_numDose":"38","status":"entered-in-error","paciente_dataNascimento":"1957-11-11","vacina_grupoAtendimento_codigo":"000201","document_id":"5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0","paciente_racaCor_codigo":"99","vacina_dataAplicacao":"2021-12-09T00:00:00.000Z","paciente_endereco_cep":"None","paciente_endereco_nmPais":"BRASIL","vacina_categoria_nome":"Faixa Etária","vacina_fabricante_referencia":"Organization/28290","paciente_endereco_coIbgeMunicipio":"291080","paciente_idade":64,"paciente_endereco_nmMunicipio":"FEIRA DE SANTANA","estalecimento_noFantasia":"UBS NOSSA SENHORA DE FATIMA","id_sistema_origem":"16341","estabelecimento_municipio_nome":"FEIRA DE SANTANA","@version":"1","dt_deleted":"2022-08-21T00:00:00.000Z","vacina_grupoAtendimento_nome":"Pessoas de 18 a 64 anos"}},{"_index":"desc-imunizacao-v5","_type":"_doc","_id":"36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0","_score":1.0,"_source":{"sistema_origem":"Novo PNI","paciente_endereco_coPais":"10","vacina_codigo":"86","vacina_fabricante_nome":"SINOVAC/BUTANTAN","vacina_nome":"COVID-19 SINOVAC/BUTANTAN - CORONAVAC","estabelecimento_razaoSocial":"SECRETARIA MUNICIPAL DE SAUDE","paciente_enumSexoBiologico":"F","paciente_endereco_uf":"RJ","data_importacao_rnds":"2021-04-28T18:58:53.000Z","paciente_racaCor_valor":"BRANCA","vacina_categoria_codigo":"3","estabelecimento_valor":"2297655","paciente_id":"9f76f7732a350ef755d6ebb33889ab6691d2b3cb7c87f54afa1fc6e8365fe9de","vacina_lote":"200280","data_importacao_datalake":"2022-08-21T18:14:52.000Z","estabelecimento_uf":"RJ","@timestamp":"2022-08-21T21:15:50.455Z","paciente_nacionalidade_enumNacionalidade":"B","estabelecimento_municipio_codigo":"330580","vacina_descricao_dose":"2ª Dose","vacina_numDose":"2","status":"entered-in-error","paciente_dataNascimento":"1942-10-22","vacina_grupoAtendimento_codigo":"000301","document_id":"36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0","paciente_racaCor_codigo":"01","vacina_dataAplicacao":"2021-03-22T00:00:00.000Z","paciente_endereco_cep":"","paciente_endereco_nmPais":"BRASIL","vacina_categoria_nome":"Pessoas de 60 anos ou mais institucionalizadas","vacina_fabricante_referencia":"Organization/61189445000156","paciente_endereco_coIbgeMunicipio":"330580","paciente_idade":78,"paciente_endereco_nmMunicipio":"TERESOPOLIS","estalecimento_noFantasia":"CENTRO MUNICIPAL DE SAUDE DR ADALBERTO OTTO","id_sistema_origem":"16341","estabelecimento_municipio_nome":"TERESOPOLIS","@version":"1","dt_deleted":"2022-08-21T00:00:00.000Z","vacina_grupoAtendimento_nome":"Pessoas de 60 nos ou mais Institucionalizadas"}},{"_index":"desc-imunizacao-v5","_type":"_doc","_id":"fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0","_score":1.0,"_source":{"sistema_origem":"VACIVIDA","paciente_endereco_coPais":"10","vacina_codigo":"85","vacina_fabricante_nome":"ASTRAZENECA/FIOCRUZ","vacina_nome":"COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD","estabelecimento_razaoSocial":"PREFEIT ...

# %%
response.json()
# Out:
# {'took': 9,
#  'timed_out': False,
#  '_shards': {'total': 30, 'successful': 30, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'Novo PNI',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '87',
#      'vacina_fabricante_nome': 'PFIZER',
#      'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#      'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FEIRA DE SANTANA',
#      'paciente_enumSexoBiologico': 'M',
#      'paciente_endereco_uf': 'BA',
#      'data_importacao_rnds': '2022-02-23T02:54:50.000Z',
#      'paciente_racaCor_valor': 'SEM INFORMACAO',
#      'vacina_categoria_codigo': '2',
#      'estabelecimento_valor': '2401533',
#      'paciente_id': 'f9fcda12d805c5a751c3dbdaf58e86dc2048c6ea057d3e3e6396da07273768d4',
#      'vacina_lote': 'FM3457',
#      'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#      'estabelecimento_uf': 'BA',
#      '@timestamp': '2022-08-21T21:15:50.452Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '291080',
#      'vacina_descricao_dose': 'Reforço',
#      'vacina_numDose': '38',
#      'status': 'entered-in-error',
#      'paciente_dataNascimento': '1957-11-11',
#      'vacina_grupoAtendimento_codigo': '000201',
#      'document_id': '5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0',
#      'paciente_racaCor_codigo': '99',
#      'vacina_dataAplicacao': '2021-12-09T00:00:00.000Z',
#      'paciente_endereco_cep': 'None',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Faixa Etária',
#      'vacina_fabricante_referencia': 'Organization/28290',
#      'paciente_endereco_coIbgeMunicipio': '291080',
#      'paciente_idade': 64,
#      'paciente_endereco_nmMunicipio': 'FEIRA DE SANTANA',
#      'estalecimento_noFantasia': 'UBS NOSSA SENHORA DE FATIMA',
#      'id_sistema_origem': '16341',
#      'estabelecimento_municipio_nome': 'FEIRA DE SANTANA',
#      '@version': '1',
#      'dt_deleted': '2022-08-21T00:00:00.000Z',
#      'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'Novo PNI',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '86',
#      'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#      'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#      'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'RJ',
#      'data_importacao_rnds': '2021-04-28T18:58:53.000Z',
#      'paciente_racaCor_valor': 'BRANCA',
#      'vacina_categoria_codigo': '3',
#      'estabelecimento_valor': '2297655',
#      'paciente_id': '9f76f7732a350ef755d6ebb33889ab6691d2b3cb7c87f54afa1fc6e8365fe9de',
#      'vacina_lote': '200280',
#      'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#      'estabelecimento_uf': 'RJ',
#      '@timestamp': '2022-08-21T21:15:50.455Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '330580',
#      'vacina_descricao_dose': '2ª Dose',
#      'vacina_numDose': '2',
#      'status': 'entered-in-error',
#      'paciente_dataNascimento': '1942-10-22',
#      'vacina_grupoAtendimento_codigo': '000301',
#      'document_id': '36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0',
#      'paciente_racaCor_codigo': '01',
#      'vacina_dataAplicacao': '2021-03-22T00:00:00.000Z',
#      'paciente_endereco_cep': '',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Pessoas de 60 anos ou mais institucionalizadas',
#      'vacina_fabricante_referencia': 'Organization/61189445000156',
#      'paciente_endereco_coIbgeMunicipio': '330580',
#      'paciente_idade': 78,
#      'paciente_endereco_nmMunicipio': 'TERESOPOLIS',
#      'estalecimento_noFantasia': 'CENTRO MUNICIPAL DE SAUDE DR ADALBERTO OTTO',
#      'id_sistema_origem': '16341',
#      'estabelecimento_municipio_nome': 'TERESOPOLIS',
#      '@version': '1',
#      'dt_deleted': '2022-08-21T00:00:00.000Z',
#      'vacina_grupoAtendimento_nome': 'Pessoas de 60 nos ou mais Institucionalizadas'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'VACIVIDA',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'AL',
#      'data_importacao_rnds': '2022-08-21T17:08:24.000Z',
#      'paciente_racaCor_valor': 'SEM INFORMACAO',
#      'vacina_categoria_codigo': '2',
#      'estabelecimento_valor': '2788144',
#      'paciente_id': '0a6199f4b4145b69ec2ee7e06dd71c2743d91fda02fa35612e3646b58de9177f',
#      'vacina_lote': '221VCD038Z',
#      'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#      'estabelecimento_uf': 'SP',
#      '@timestamp': '2022-08-21T21:15:50.456Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '355030',
#      'vacina_descricao_dose': 'Reforço',
#      'vacina_numDose': '38',
#      'status': 'entered-in-error',
#      'paciente_dataNascimento': '1995-09-01',
#      'vacina_grupoAtendimento_codigo': '000201',
#      'document_id': 'fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0',
#      'paciente_racaCor_codigo': '99',
#      'vacina_dataAplicacao': '2022-08-21T00:00:00.000Z',
#      'paciente_endereco_cep': '57035',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Faixa Etária',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '270430',
#      'paciente_idade': 26,
#      'paciente_endereco_nmMunicipio': 'MACEIO',
#      'estalecimento_noFantasia': 'UBS NOSSA S DO BRASIL ARMANDO DARIENZO',
#      'id_sistema_origem': '18262',
#      'estabelecimento_municipio_nome': 'SAO PAULO',
#      '@version': '1',
#      'dt_deleted': '2022-08-21T00:00:00.000Z',
#      'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '03fdf6c9-e439-4b8b-b350-b7d970eacdbe-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'VACIVIDA',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'MG',
#      'data_importacao_rnds': '2022-08-21T16:08:23.000Z',
#      'paciente_racaCor_valor': 'SEM INFORMACAO',
#      'vacina_categoria_codigo': '1',
#      'estabelecimento_valor': '2752336',
#      'paciente_id': 'e717dee13b08afe3eef04911c88cc8201aded0534b915725c8d3118d26c39016',
#      'vacina_lote': '221VCD038Z',
#      'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#      'estabelecimento_uf': 'SP',
#      '@timestamp': '2022-08-21T21:15:50.456Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '355030',
#      'vacina_descricao_dose': 'Reforço',
#      'vacina_numDose': '38',
#      'status': 'entered-in-error',
#      'paciente_dataNascimento': '1968-04-23',
#      'vacina_grupoAtendimento_codigo': '000102',
#      'document_id': '03fdf6c9-e439-4b8b-b350-b7d970eacdbe-i0b0',
#      'paciente_racaCor_codigo': '99',
#      'vacina_dataAplicacao': '2022-08-21T00:00:00.000Z',
#      'paciente_endereco_cep': '38183',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Comorbidades',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '310400',
#      'paciente_idade': 54,
#      'paciente_endereco_nmMunicipio': 'ARAXA',
#      'estalecimento_noFantasia': 'UBS DR HUMBERTO PASCALE SANTA CECILIA',
#      'id_sistema_origem': '18262',
#      'estabelecimento_municipio_nome': 'SAO PAULO',
#      '@version': '1',
#      'dt_deleted': '2022-08-21T00:00:00.000Z',
#      'vacina_grupoAtendimento_nome': 'Neoplasias'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'ca8cda95-eb99-4712-a0bc-f89b751e4b23-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'VACINA E CONFIA ES',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '86',
#      'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#      'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#      'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DA SERRA',
#      'paciente_enumSexoBiologico': 'M',
#      'paciente_endereco_uf': 'ES',
#      'data_importacao_rnds': '2022-08-20T15:30:27.000Z',
#      'paciente_racaCor_valor': 'AMARELA',
#      'vacina_categoria_codigo': None,
#      'estabelecimento_valor': '2499460',
#      'paciente_id': '81572a1d2c268b029a7237670b954cd8e929b9bcd9570878cdfdfbf069b184c5',
#      'vacina_lote': '210477',
#      'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#      'estabelecimento_uf': 'ES',
#      '@timestamp': '2022-08-21T21:15:50.458Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '320500',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'entered-in-error',
#      'paciente_dataNascimento': '2011-01-09',
#      'vacina_grupoAtendimento_codigo': '000207',
#      'document_id': 'ca8cda95-eb99-4712-a0bc-f89b751e4b23-i0b0',
#      'paciente_racaCor_codigo': '04',
#      'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#      'paciente_endereco_cep': '29171',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': None,
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '320500',
#      'paciente_idade': 11,
#      'paciente_endereco_nmMunicipio': 'SERRA',
#      'estalecimento_noFantasia': 'ESF DE MANGUINHOS',
#      'id_sistema_origem': '24294',
#      'estabelecimento_municipio_nome': 'SERRA',
#      '@version': '1',
#      'dt_deleted': '2022-08-21T00:00:00.000Z',
#      'vacina_grupoAtendimento_nome': 'Pessoas de 5 a 11 anos'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'd9a6d40c-df7f-4fec-8af9-9243321874e5-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'Novo PNI',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'MUNICIPIO DE BARRA DO PIRAI',
#      'paciente_enumSexoBiologico': 'M',
#      'paciente_endereco_uf': 'RJ',
#      'data_importacao_rnds': '2022-08-21T12:52:09.000Z',
#      'paciente_racaCor_valor': 'BRANCA',
#      'vacina_categoria_codigo': '2',
#      'estabelecimento_valor': '2287757',
#      'paciente_id': 'a5902998cb61637ae885b7fbdc6dd45ff456bf4d83041f45d62b935eef31a312',
#      'vacina_lote': '21PVCD390W',
#      'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#      'estabelecimento_uf': 'RJ',
#      '@timestamp': '2022-08-21T21:15:49.748Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '330030',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'final',
#      'paciente_dataNascimento': '2001-04-06',
#      'vacina_grupoAtendimento_codigo': '000201',
#      'document_id': 'd9a6d40c-df7f-4fec-8af9-9243321874e5-i0b0',
#      'paciente_racaCor_codigo': '01',
#      'vacina_dataAplicacao': '2022-08-04T00:00:00.000Z',
#      'paciente_endereco_cep': '27113',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Faixa Etária',
#      'vacina_fabricante_referencia': '149',
#      'paciente_endereco_coIbgeMunicipio': '330030',
#      'paciente_idade': 21,
#      'paciente_endereco_nmMunicipio': 'BARRA DO PIRAI',
#      'estalecimento_noFantasia': 'POSTO DE SAUDE ALBERT SABIN',
#      'id_sistema_origem': '16341',
#      'estabelecimento_municipio_nome': 'BARRA DO PIRAI',
#      '@version': '1',
#      'dt_deleted': None,
#      'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '2bf8fbaf-dac4-4ce7-949e-2ed12834f1e6-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'RN + Vacina',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'MUNICIPIO DE PARNAMIRIM',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'RN',
#      'data_importacao_rnds': '2022-08-21T06:08:50.000Z',
#      'paciente_racaCor_valor': 'BRANCA',
#      'vacina_categoria_codigo': '9',
#      'estabelecimento_valor': '2473224',
#      'paciente_id': '4f304005e2ada1f8a7f366f5042d6b772e88636a773297444df22e80917f3295',
#      'vacina_lote': '222VCD045W',
#      'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#      'estabelecimento_uf': 'RN',
#      '@timestamp': '2022-08-21T21:15:49.748Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '240325',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'final',
#      'paciente_dataNascimento': '1981-04-22',
#      'vacina_grupoAtendimento_codigo': '000926',
#      'document_id': '2bf8fbaf-dac4-4ce7-949e-2ed12834f1e6-i0b0',
#      'paciente_racaCor_codigo': '01',
#      'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#      'paciente_endereco_cep': '59149',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Trabalhadores de Saúde',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '240325',
#      'paciente_idade': 41,
#      'paciente_endereco_nmMunicipio': 'PARNAMIRIM',
#      'estalecimento_noFantasia': 'UBS EMAUS II PARQUE INDUSTRIAL DR VULPIANO CAVALCANTE',
#      'id_sistema_origem': '17862',
#      'estabelecimento_municipio_nome': 'PARNAMIRIM',
#      '@version': '1',
#      'dt_deleted': None,
#      'vacina_grupoAtendimento_nome': 'Outros'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '374d1088-67e6-4186-9891-0bbf306e7657-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'RN + Vacina',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '87',
#      'vacina_fabricante_nome': 'PFIZER',
#      'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#      'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE DE NATAL',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'RN',
#      'data_importacao_rnds': '2022-08-21T06:21:55.000Z',
#      'paciente_racaCor_valor': 'PARDA',
#      'vacina_categoria_codigo': '9',
#      'estabelecimento_valor': '6347223',
#      'paciente_id': 'b95f7dce12241b799482d26f9b47d807bff01701adf16b75ba7af367b931534b',
#      'vacina_lote': 'FP8544',
#      'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#      'estabelecimento_uf': 'RN',
#      '@timestamp': '2022-08-21T21:15:49.748Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '240810',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'final',
#      'paciente_dataNascimento': '1986-01-27',
#      'vacina_grupoAtendimento_codigo': '000926',
#      'document_id': '374d1088-67e6-4186-9891-0bbf306e7657-i0b0',
#      'paciente_racaCor_codigo': '03',
#      'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#      'paciente_endereco_cep': '59230',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Trabalhadores de Saúde',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '240210',
#      'paciente_idade': 36,
#      'paciente_endereco_nmMunicipio': 'CAMPO REDONDO',
#      'estalecimento_noFantasia': 'SECRETARIA MUNICIPAL DE SAUDE NIVEL CENTRAL',
#      'id_sistema_origem': '17862',
#      'estabelecimento_municipio_nome': 'NATAL',
#      '@version': '1',
#      'dt_deleted': None,
#      'vacina_grupoAtendimento_nome': 'Outros'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'e1a1567f-a60b-42f5-950a-574fc26099e3-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'RN + Vacina',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'MUNICIPIO DE EXTREMOZ',
#      'paciente_enumSexoBiologico': 'M',
#      'paciente_endereco_uf': 'RN',
#      'data_importacao_rnds': '2022-08-21T06:33:02.000Z',
#      'paciente_racaCor_valor': 'PARDA',
#      'vacina_categoria_codigo': '9',
#      'estabelecimento_valor': '2409305',
#      'paciente_id': '7b5e418ff766c5ae298983bebf1035e71a831fc2e9ccd03a3fa8819b88088d2c',
#      'vacina_lote': '222VCD045W',
#      'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#      'estabelecimento_uf': 'RN',
#      '@timestamp': '2022-08-21T21:15:49.749Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '240360',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'final',
#      'paciente_dataNascimento': '1989-03-07',
#      'vacina_grupoAtendimento_codigo': '000926',
#      'document_id': 'e1a1567f-a60b-42f5-950a-574fc26099e3-i0b0',
#      'paciente_racaCor_codigo': '03',
#      'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#      'paciente_endereco_cep': '59575',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Trabalhadores de Saúde',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '240360',
#      'paciente_idade': 33,
#      'paciente_endereco_nmMunicipio': 'EXTREMOZ',
#      'estalecimento_noFantasia': 'UBS VILA DE FATIMA',
#      'id_sistema_origem': '17862',
#      'estabelecimento_municipio_nome': 'EXTREMOZ',
#      '@version': '1',
#      'dt_deleted': None,
#      'vacina_grupoAtendimento_nome': 'Outros'}},
#    {'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'f6702fe7-45f8-40aa-9735-e9e443c56c24-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'RN + Vacina',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '88',
#      'vacina_fabricante_nome': 'JANSSEN',
#      'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#      'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE SAO GONCALO DO AMARANTE',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'RN',
#      'data_importacao_rnds': '2022-08-21T09:30:42.000Z',
#      'paciente_racaCor_valor': 'AMARELA',
#      'vacina_categoria_codigo': '9',
#      'estabelecimento_valor': '2375567',
#      'paciente_id': 'be3c528b6ec744f65703cdcbb76012f13059896c5db5b397ad07b3a16c8380ac',
#      'vacina_lote': '211J21A',
#      'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#      'estabelecimento_uf': 'RN',
#      '@timestamp': '2022-08-21T21:15:49.753Z',
#      'paciente_nacionalidade_enumNacionalidade': 'B',
#      'estabelecimento_municipio_codigo': '241200',
#      'vacina_descricao_dose': '2º Reforço',
#      'vacina_numDose': '7',
#      'status': 'final',
#      'paciente_dataNascimento': '1974-05-01',
#      'vacina_grupoAtendimento_codigo': '000926',
#      'document_id': 'f6702fe7-45f8-40aa-9735-e9e443c56c24-i0b0',
#      'paciente_racaCor_codigo': '04',
#      'vacina_dataAplicacao': '2022-08-19T00:00:00.000Z',
#      'paciente_endereco_cep': '59104',
#      'paciente_endereco_nmPais': 'BRASIL',
#      'vacina_categoria_nome': 'Trabalhadores de Saúde',
#      'vacina_fabricante_referencia': None,
#      'paciente_endereco_coIbgeMunicipio': '240810',
#      'paciente_idade': 48,
#      'paciente_endereco_nmMunicipio': 'NATAL',
#      'estalecimento_noFantasia': 'UBS REGO MOLEIRO VEREADORA MARIA DO CARMO DE BRITO',
#      'id_sistema_origem': '17862',
#      'estabelecimento_municipio_nome': 'SAO GONCALO DO AMARANTE',
#      '@version': '1',
#      'dt_deleted': None,
#      'vacina_grupoAtendimento_nome': 'Outros'}}]}}

# %%
vacina = response.json()

# %%
vacina['hits']['hits']
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '87',
#    'vacina_fabricante_nome': 'PFIZER',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FEIRA DE SANTANA',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_uf': 'BA',
#    'data_importacao_rnds': '2022-02-23T02:54:50.000Z',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'vacina_categoria_codigo': '2',
#    'estabelecimento_valor': '2401533',
#    'paciente_id': 'f9fcda12d805c5a751c3dbdaf58e86dc2048c6ea057d3e3e6396da07273768d4',
#    'vacina_lote': 'FM3457',
#    'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#    'estabelecimento_uf': 'BA',
#    '@timestamp': '2022-08-21T21:15:50.452Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '291080',
#    'vacina_descricao_dose': 'Reforço',
#    'vacina_numDose': '38',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '1957-11-11',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'document_id': '5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0',
#    'paciente_racaCor_codigo': '99',
#    'vacina_dataAplicacao': '2021-12-09T00:00:00.000Z',
#    'paciente_endereco_cep': 'None',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': 'Organization/28290',
#    'paciente_endereco_coIbgeMunicipio': '291080',
#    'paciente_idade': 64,
#    'paciente_endereco_nmMunicipio': 'FEIRA DE SANTANA',
#    'estalecimento_noFantasia': 'UBS NOSSA SENHORA DE FATIMA',
#    'id_sistema_origem': '16341',
#    'estabelecimento_municipio_nome': 'FEIRA DE SANTANA',
#    '@version': '1',
#    'dt_deleted': '2022-08-21T00:00:00.000Z',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '86',
#    'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#    'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#    'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'RJ',
#    'data_importacao_rnds': '2021-04-28T18:58:53.000Z',
#    'paciente_racaCor_valor': 'BRANCA',
#    'vacina_categoria_codigo': '3',
#    'estabelecimento_valor': '2297655',
#    'paciente_id': '9f76f7732a350ef755d6ebb33889ab6691d2b3cb7c87f54afa1fc6e8365fe9de',
#    'vacina_lote': '200280',
#    'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#    'estabelecimento_uf': 'RJ',
#    '@timestamp': '2022-08-21T21:15:50.455Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '330580',
#    'vacina_descricao_dose': '2ª Dose',
#    'vacina_numDose': '2',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '1942-10-22',
#    'vacina_grupoAtendimento_codigo': '000301',
#    'document_id': '36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0',
#    'paciente_racaCor_codigo': '01',
#    'vacina_dataAplicacao': '2021-03-22T00:00:00.000Z',
#    'paciente_endereco_cep': '',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Pessoas de 60 anos ou mais institucionalizadas',
#    'vacina_fabricante_referencia': 'Organization/61189445000156',
#    'paciente_endereco_coIbgeMunicipio': '330580',
#    'paciente_idade': 78,
#    'paciente_endereco_nmMunicipio': 'TERESOPOLIS',
#    'estalecimento_noFantasia': 'CENTRO MUNICIPAL DE SAUDE DR ADALBERTO OTTO',
#    'id_sistema_origem': '16341',
#    'estabelecimento_municipio_nome': 'TERESOPOLIS',
#    '@version': '1',
#    'dt_deleted': '2022-08-21T00:00:00.000Z',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 60 nos ou mais Institucionalizadas'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'AL',
#    'data_importacao_rnds': '2022-08-21T17:08:24.000Z',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'vacina_categoria_codigo': '2',
#    'estabelecimento_valor': '2788144',
#    'paciente_id': '0a6199f4b4145b69ec2ee7e06dd71c2743d91fda02fa35612e3646b58de9177f',
#    'vacina_lote': '221VCD038Z',
#    'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#    'estabelecimento_uf': 'SP',
#    '@timestamp': '2022-08-21T21:15:50.456Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '355030',
#    'vacina_descricao_dose': 'Reforço',
#    'vacina_numDose': '38',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '1995-09-01',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'document_id': 'fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0',
#    'paciente_racaCor_codigo': '99',
#    'vacina_dataAplicacao': '2022-08-21T00:00:00.000Z',
#    'paciente_endereco_cep': '57035',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '270430',
#    'paciente_idade': 26,
#    'paciente_endereco_nmMunicipio': 'MACEIO',
#    'estalecimento_noFantasia': 'UBS NOSSA S DO BRASIL ARMANDO DARIENZO',
#    'id_sistema_origem': '18262',
#    'estabelecimento_municipio_nome': 'SAO PAULO',
#    '@version': '1',
#    'dt_deleted': '2022-08-21T00:00:00.000Z',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '03fdf6c9-e439-4b8b-b350-b7d970eacdbe-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'MG',
#    'data_importacao_rnds': '2022-08-21T16:08:23.000Z',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'vacina_categoria_codigo': '1',
#    'estabelecimento_valor': '2752336',
#    'paciente_id': 'e717dee13b08afe3eef04911c88cc8201aded0534b915725c8d3118d26c39016',
#    'vacina_lote': '221VCD038Z',
#    'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#    'estabelecimento_uf': 'SP',
#    '@timestamp': '2022-08-21T21:15:50.456Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '355030',
#    'vacina_descricao_dose': 'Reforço',
#    'vacina_numDose': '38',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '1968-04-23',
#    'vacina_grupoAtendimento_codigo': '000102',
#    'document_id': '03fdf6c9-e439-4b8b-b350-b7d970eacdbe-i0b0',
#    'paciente_racaCor_codigo': '99',
#    'vacina_dataAplicacao': '2022-08-21T00:00:00.000Z',
#    'paciente_endereco_cep': '38183',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Comorbidades',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '310400',
#    'paciente_idade': 54,
#    'paciente_endereco_nmMunicipio': 'ARAXA',
#    'estalecimento_noFantasia': 'UBS DR HUMBERTO PASCALE SANTA CECILIA',
#    'id_sistema_origem': '18262',
#    'estabelecimento_municipio_nome': 'SAO PAULO',
#    '@version': '1',
#    'dt_deleted': '2022-08-21T00:00:00.000Z',
#    'vacina_grupoAtendimento_nome': 'Neoplasias'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'ca8cda95-eb99-4712-a0bc-f89b751e4b23-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACINA E CONFIA ES',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '86',
#    'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#    'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DA SERRA',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_uf': 'ES',
#    'data_importacao_rnds': '2022-08-20T15:30:27.000Z',
#    'paciente_racaCor_valor': 'AMARELA',
#    'vacina_categoria_codigo': None,
#    'estabelecimento_valor': '2499460',
#    'paciente_id': '81572a1d2c268b029a7237670b954cd8e929b9bcd9570878cdfdfbf069b184c5',
#    'vacina_lote': '210477',
#    'data_importacao_datalake': '2022-08-21T18:14:52.000Z',
#    'estabelecimento_uf': 'ES',
#    '@timestamp': '2022-08-21T21:15:50.458Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '320500',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '2011-01-09',
#    'vacina_grupoAtendimento_codigo': '000207',
#    'document_id': 'ca8cda95-eb99-4712-a0bc-f89b751e4b23-i0b0',
#    'paciente_racaCor_codigo': '04',
#    'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#    'paciente_endereco_cep': '29171',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': None,
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '320500',
#    'paciente_idade': 11,
#    'paciente_endereco_nmMunicipio': 'SERRA',
#    'estalecimento_noFantasia': 'ESF DE MANGUINHOS',
#    'id_sistema_origem': '24294',
#    'estabelecimento_municipio_nome': 'SERRA',
#    '@version': '1',
#    'dt_deleted': '2022-08-21T00:00:00.000Z',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 5 a 11 anos'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'd9a6d40c-df7f-4fec-8af9-9243321874e5-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BARRA DO PIRAI',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_uf': 'RJ',
#    'data_importacao_rnds': '2022-08-21T12:52:09.000Z',
#    'paciente_racaCor_valor': 'BRANCA',
#    'vacina_categoria_codigo': '2',
#    'estabelecimento_valor': '2287757',
#    'paciente_id': 'a5902998cb61637ae885b7fbdc6dd45ff456bf4d83041f45d62b935eef31a312',
#    'vacina_lote': '21PVCD390W',
#    'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#    'estabelecimento_uf': 'RJ',
#    '@timestamp': '2022-08-21T21:15:49.748Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '330030',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'final',
#    'paciente_dataNascimento': '2001-04-06',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'document_id': 'd9a6d40c-df7f-4fec-8af9-9243321874e5-i0b0',
#    'paciente_racaCor_codigo': '01',
#    'vacina_dataAplicacao': '2022-08-04T00:00:00.000Z',
#    'paciente_endereco_cep': '27113',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': '149',
#    'paciente_endereco_coIbgeMunicipio': '330030',
#    'paciente_idade': 21,
#    'paciente_endereco_nmMunicipio': 'BARRA DO PIRAI',
#    'estalecimento_noFantasia': 'POSTO DE SAUDE ALBERT SABIN',
#    'id_sistema_origem': '16341',
#    'estabelecimento_municipio_nome': 'BARRA DO PIRAI',
#    '@version': '1',
#    'dt_deleted': None,
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '2bf8fbaf-dac4-4ce7-949e-2ed12834f1e6-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'RN + Vacina',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE PARNAMIRIM',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'RN',
#    'data_importacao_rnds': '2022-08-21T06:08:50.000Z',
#    'paciente_racaCor_valor': 'BRANCA',
#    'vacina_categoria_codigo': '9',
#    'estabelecimento_valor': '2473224',
#    'paciente_id': '4f304005e2ada1f8a7f366f5042d6b772e88636a773297444df22e80917f3295',
#    'vacina_lote': '222VCD045W',
#    'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#    'estabelecimento_uf': 'RN',
#    '@timestamp': '2022-08-21T21:15:49.748Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '240325',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'final',
#    'paciente_dataNascimento': '1981-04-22',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'document_id': '2bf8fbaf-dac4-4ce7-949e-2ed12834f1e6-i0b0',
#    'paciente_racaCor_codigo': '01',
#    'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#    'paciente_endereco_cep': '59149',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '240325',
#    'paciente_idade': 41,
#    'paciente_endereco_nmMunicipio': 'PARNAMIRIM',
#    'estalecimento_noFantasia': 'UBS EMAUS II PARQUE INDUSTRIAL DR VULPIANO CAVALCANTE',
#    'id_sistema_origem': '17862',
#    'estabelecimento_municipio_nome': 'PARNAMIRIM',
#    '@version': '1',
#    'dt_deleted': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '374d1088-67e6-4186-9891-0bbf306e7657-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'RN + Vacina',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '87',
#    'vacina_fabricante_nome': 'PFIZER',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE DE NATAL',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'RN',
#    'data_importacao_rnds': '2022-08-21T06:21:55.000Z',
#    'paciente_racaCor_valor': 'PARDA',
#    'vacina_categoria_codigo': '9',
#    'estabelecimento_valor': '6347223',
#    'paciente_id': 'b95f7dce12241b799482d26f9b47d807bff01701adf16b75ba7af367b931534b',
#    'vacina_lote': 'FP8544',
#    'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#    'estabelecimento_uf': 'RN',
#    '@timestamp': '2022-08-21T21:15:49.748Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '240810',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'final',
#    'paciente_dataNascimento': '1986-01-27',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'document_id': '374d1088-67e6-4186-9891-0bbf306e7657-i0b0',
#    'paciente_racaCor_codigo': '03',
#    'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#    'paciente_endereco_cep': '59230',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '240210',
#    'paciente_idade': 36,
#    'paciente_endereco_nmMunicipio': 'CAMPO REDONDO',
#    'estalecimento_noFantasia': 'SECRETARIA MUNICIPAL DE SAUDE NIVEL CENTRAL',
#    'id_sistema_origem': '17862',
#    'estabelecimento_municipio_nome': 'NATAL',
#    '@version': '1',
#    'dt_deleted': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'e1a1567f-a60b-42f5-950a-574fc26099e3-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'RN + Vacina',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE EXTREMOZ',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_uf': 'RN',
#    'data_importacao_rnds': '2022-08-21T06:33:02.000Z',
#    'paciente_racaCor_valor': 'PARDA',
#    'vacina_categoria_codigo': '9',
#    'estabelecimento_valor': '2409305',
#    'paciente_id': '7b5e418ff766c5ae298983bebf1035e71a831fc2e9ccd03a3fa8819b88088d2c',
#    'vacina_lote': '222VCD045W',
#    'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#    'estabelecimento_uf': 'RN',
#    '@timestamp': '2022-08-21T21:15:49.749Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '240360',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'final',
#    'paciente_dataNascimento': '1989-03-07',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'document_id': 'e1a1567f-a60b-42f5-950a-574fc26099e3-i0b0',
#    'paciente_racaCor_codigo': '03',
#    'vacina_dataAplicacao': '2022-08-20T00:00:00.000Z',
#    'paciente_endereco_cep': '59575',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '240360',
#    'paciente_idade': 33,
#    'paciente_endereco_nmMunicipio': 'EXTREMOZ',
#    'estalecimento_noFantasia': 'UBS VILA DE FATIMA',
#    'id_sistema_origem': '17862',
#    'estabelecimento_municipio_nome': 'EXTREMOZ',
#    '@version': '1',
#    'dt_deleted': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'f6702fe7-45f8-40aa-9735-e9e443c56c24-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'RN + Vacina',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '88',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE SAO GONCALO DO AMARANTE',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'RN',
#    'data_importacao_rnds': '2022-08-21T09:30:42.000Z',
#    'paciente_racaCor_valor': 'AMARELA',
#    'vacina_categoria_codigo': '9',
#    'estabelecimento_valor': '2375567',
#    'paciente_id': 'be3c528b6ec744f65703cdcbb76012f13059896c5db5b397ad07b3a16c8380ac',
#    'vacina_lote': '211J21A',
#    'data_importacao_datalake': '2022-08-21T18:07:55.000Z',
#    'estabelecimento_uf': 'RN',
#    '@timestamp': '2022-08-21T21:15:49.753Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_codigo': '241200',
#    'vacina_descricao_dose': '2º Reforço',
#    'vacina_numDose': '7',
#    'status': 'final',
#    'paciente_dataNascimento': '1974-05-01',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'document_id': 'f6702fe7-45f8-40aa-9735-e9e443c56c24-i0b0',
#    'paciente_racaCor_codigo': '04',
#    'vacina_dataAplicacao': '2022-08-19T00:00:00.000Z',
#    'paciente_endereco_cep': '59104',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_coIbgeMunicipio': '240810',
#    'paciente_idade': 48,
#    'paciente_endereco_nmMunicipio': 'NATAL',
#    'estalecimento_noFantasia': 'UBS REGO MOLEIRO VEREADORA MARIA DO CARMO DE BRITO',
#    'id_sistema_origem': '17862',
#    'estabelecimento_municipio_nome': 'SAO GONCALO DO AMARANTE',
#    '@version': '1',
#    'dt_deleted': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}}]

# %%
df_vacina = pd.json_normalize(vacina['hits']['hits'])

# %%
df_vacina
# Out:
#                _index _type                                        _id  \
# 0  desc-imunizacao-v5  _doc  5e0e4cec-e30a-4115-a315-ed77d5e591b0-i0b0
# 1  desc-imunizacao-v5  _doc  36ece186-d58f-4d92-9071-1c2c4eb97e66-i0b0
# 2  desc-imunizacao-v5  _doc  fbfac0cb-e8a1-4526-843b-1f9cbed157ee-i0b0
# 3  desc-imunizacao-v5  _doc  03fdf6c9-e439-4b8b-b350-b7d970eacdbe-i0b0
# 4  desc-imunizacao-v5  _doc  ca8cda95-eb99-4712-a0bc-f89b751e4b23-i0b0
# 5  desc-imunizacao-v5  _doc  d9a6d40c-df7f-4fec-8af9-9243321874e5-i0b0
# 6  desc-imunizacao-v5  _doc  2bf8fbaf-dac4-4ce7-949e-2ed12834f1e6-i0b0
# 7  desc-imunizacao-v5  _doc  374d1088-67e6-4186-9891-0bbf306e7657-i0b0
# 8  desc-imunizacao-v5  _doc  e1a1567f-a60b-42f5-950a-574fc26099e3-i0b0
# 9  desc-imunizacao-v5  _doc  f6702fe7-45f8-40aa-9735-e9e443c56c24-i0b0
#
#    _score _source.sistema_origem _source.paciente_endereco_coPais  \
# 0     1.0               Novo PNI                               10
# 1     1.0               Novo PNI                               10
# 2     1.0               VACIVIDA                               10
# 3     1.0               VACIVIDA                               10
# 4     1.0     VACINA E CONFIA ES                               10
# 5     1.0               Novo PNI                               10
# 6     1.0            RN + Vacina                               10
# 7     1.0            RN + Vacina                               10
# 8     1.0            RN + Vacina                               10
# 9     1.0            RN + Vacina                               10
#
#   _source.vacina_codigo _source.vacina_fabricante_nome  \
# 0                    87                         PFIZER
# 1                    86               SINOVAC/BUTANTAN
# 2                    85            ASTRAZENECA/FIOCRUZ
# 3                    85            ASTRAZENECA/FIOCRUZ
# 4                    86               SINOVAC/BUTANTAN
# 5                    85            ASTRAZENECA/FIOCRUZ
# 6                    85            ASTRAZENECA/FIOCRUZ
# 7                    87                         PFIZER
# 8                    85            ASTRAZENECA/FIOCRUZ
# 9                    88                        JANSSEN
#
#                          _source.vacina_nome  \
# 0                COVID-19 PFIZER - COMIRNATY
# 1      COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 2  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 3  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 4      COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 5  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 6  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 7                COVID-19 PFIZER - COMIRNATY
# 8  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 9             COVID-19 JANSSEN - Ad26.COV2.S
#
#                _source.estabelecimento_razaoSocial  ...  \
# 0         PREFEITURA MUNICIPAL DE FEIRA DE SANTANA  ...
# 1                    SECRETARIA MUNICIPAL DE SAUDE  ...
# 2             PREFEITURA DO MUNICIPIO DE SAO PAULO  ...
# 3             PREFEITURA DO MUNICIPIO DE SAO PAULO  ...
# 4                    PREFEITURA MUNICIPAL DA SERRA  ...
# 5                      MUNICIPIO DE BARRA DO PIRAI  ...
# 6                          MUNICIPIO DE PARNAMIRIM  ...
# 7           SECRETARIA MUNICIPAL DE SAUDE DE NATAL  ...
# 8                            MUNICIPIO DE EXTREMOZ  ...
# 9  PREFEITURA MUNICIPAL DE SAO GONCALO DO AMARANTE  ...
#
#   _source.vacina_fabricante_referencia  \
# 0                   Organization/28290
# 1          Organization/61189445000156
# 2                                 None
# 3                                 None
# 4                                 None
# 5                                  149
# 6                                 None
# 7                                 None
# 8                                 None
# 9                                 None
#
#   _source.paciente_endereco_coIbgeMunicipio _source.paciente_idade  \
# 0                                    291080                     64
# 1                                    330580                     78
# 2                                    270430                     26
# 3                                    310400                     54
# 4                                    320500                     11
# 5                                    330030                     21
# 6                                    240325                     41
# 7                                    240210                     36
# 8                                    240360                     33
# 9                                    240810                     48
#
#   _source.paciente_endereco_nmMunicipio  \
# 0                      FEIRA DE SANTANA
# 1                           TERESOPOLIS
# 2                                MACEIO
# 3                                 ARAXA
# 4                                 SERRA
# 5                        BARRA DO PIRAI
# 6                            PARNAMIRIM
# 7                         CAMPO REDONDO
# 8                              EXTREMOZ
# 9                                 NATAL
#
#                     _source.estalecimento_noFantasia  \
# 0                        UBS NOSSA SENHORA DE FATIMA
# 1        CENTRO MUNICIPAL DE SAUDE DR ADALBERTO OTTO
# 2             UBS NOSSA S DO BRASIL ARMANDO DARIENZO
# 3              UBS DR HUMBERTO PASCALE SANTA CECILIA
# 4                                  ESF DE MANGUINHOS
# 5                        POSTO DE SAUDE ALBERT SABIN
# 6  UBS EMAUS II PARQUE INDUSTRIAL DR VULPIANO CAV...
# 7        SECRETARIA MUNICIPAL DE SAUDE NIVEL CENTRAL
# 8                                 UBS VILA DE FATIMA
# 9  UBS REGO MOLEIRO VEREADORA MARIA DO CARMO DE B...
#
#   _source.id_sistema_origem _source.estabelecimento_municipio_nome  \
# 0                     16341                       FEIRA DE SANTANA
# 1                     16341                            TERESOPOLIS
# 2                     18262                              SAO PAULO
# 3                     18262                              SAO PAULO
# 4                     24294                                  SERRA
# 5                     16341                         BARRA DO PIRAI
# 6                     17862                             PARNAMIRIM
# 7                     17862                                  NATAL
# 8                     17862                               EXTREMOZ
# 9                     17862                SAO GONCALO DO AMARANTE
#
#   _source.@version        _source.dt_deleted  \
# 0                1  2022-08-21T00:00:00.000Z
# 1                1  2022-08-21T00:00:00.000Z
# 2                1  2022-08-21T00:00:00.000Z
# 3                1  2022-08-21T00:00:00.000Z
# 4                1  2022-08-21T00:00:00.000Z
# 5                1                      None
# 6                1                      None
# 7                1                      None
# 8                1                      None
# 9                1                      None
#
#             _source.vacina_grupoAtendimento_nome
# 0                        Pessoas de 18 a 64 anos
# 1  Pessoas de 60 nos ou mais Institucionalizadas
# 2                        Pessoas de 18 a 64 anos
# 3                                     Neoplasias
# 4                         Pessoas de 5 a 11 anos
# 5                        Pessoas de 18 a 64 anos
# 6                                         Outros
# 7                                         Outros
# 8                                         Outros
# 9                                         Outros
#
# [10 rows x 44 columns]
